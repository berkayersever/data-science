# %% [markdown]
# # Data Wrangling

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
from os.path import join
from pprint import pprint

# %%
d_path = "./data"
d_file = "nba_players.csv"

# %%
df = pd.read_csv(join(d_path, d_file))

# %%
df.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
print(df.columns)
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM',
#        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
n_rows, n_columns = df.shape  # get the shape of dataframe
print("number of rows: {}, number of columns: {}".format(n_rows, n_columns))
# Out:
# number of rows: 24658, number of columns: 52

# %%
df.dtypes
# Out:
# Year      float64
# Player     object
# Pos        object
# Age       float64
# Tm         object
# G         float64
# GS        float64
# MP        float64
# PER       float64
# TS%       float64
# 3PAr      float64
# FTr       float64
# ORB%      float64
# DRB%      float64
# TRB%      float64
# AST%      float64
# STL%      float64
# BLK%      float64
# TOV%      float64
# USG%      float64
# blanl     float64
# OWS       float64
# DWS       float64
# WS        float64
# WS/48     float64
# blank2    float64
# OBPM      float64
# DBPM      float64
# BPM       float64
# VORP      float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %% [markdown]
# ### Dealing with NaN values

# %%
df.isnull().sum()  # NaN counts in each column
# Out:
# Year         67
# Player       67
# Pos          67
# Age          75
# Tm           67
# G            67
# GS         6454
# MP          553
# PER         590
# TS%         153
# 3PAr       5850
# FTr         166
# ORB%       3899
# DRB%       3899
# TRB%       3120
# AST%       2136
# STL%       3899
# BLK%       3899
# TOV%       5109
# USG%       5051
# blanl     24658
# OWS         106
# DWS         106
# WS          106
# WS/48       590
# blank2    24658
# OBPM       3894
# DBPM       3894
# BPM        3894
# VORP       3894
# FG           67
# FGA          67
# FG%         166
# 3P         5762
# 3PA        5762
# 3P%        9273
# 2P           67
# 2PA          67
# 2P%         195
# eFG%        166
# FT           67
# FTA          67
# FT%         924
# ORB        3894
# DRB        3894
# TRB         379
# AST          67
# STL        3894
# BLK        3894
# TOV        5046
# PF           67
# PTS          67
# dtype: int64

# %%
na_ratios = df.isnull().sum() / n_rows  # finding the NaN value ratio of each column
                                        # it returns a series object with column names as indices
print(na_ratios)
# Out:
# Year      0.002717
# Player    0.002717
# Pos       0.002717
# Age       0.003042
# Tm        0.002717
# G         0.002717
# GS        0.261741
# MP        0.022427
# PER       0.023927
# TS%       0.006205
# 3PAr      0.237246
# FTr       0.006732
# ORB%      0.158123
# DRB%      0.158123
# TRB%      0.126531
# AST%      0.086625
# STL%      0.158123
# BLK%      0.158123
# TOV%      0.207194
# USG%      0.204842
# blanl     1.000000
# OWS       0.004299
# DWS       0.004299
# WS        0.004299
# WS/48     0.023927
# blank2    1.000000
# OBPM      0.157920
# DBPM      0.157920
# BPM       0.157920
# VORP      0.157920
# FG        0.002717
# FGA       0.002717
# FG%       0.006732
# 3P        0.233677
# 3PA       0.233677
# 3P%       0.376065
# 2P        0.002717
# 2PA       0.002717
# 2P%       0.007908
# eFG%      0.006732
# FT        0.002717
# FTA       0.002717
# FT%       0.037473
# ORB       0.157920
# DRB       0.157920
# TRB       0.015370
# AST       0.002717
# STL       0.157920
# BLK       0.157920
# TOV       0.204639
# PF        0.002717
# PTS       0.002717
# dtype: float64

# %% [markdown]
# We can see that columns **"blanl"** and **"blank2"** are completely empty. Let's remove them with `drop` function.
#
# ``` py
# >>> df.drop(columns2remove, axis=1)  # removing columns from the dataframe
#                                      # axis=1 to remove the columns
# ```

# %%
df.drop(["blanl", "blank2"], axis=1, inplace=True)  # set inplace to True
                                                    # to apply the changes to the dataframe

# %% [markdown]
# Now, let's check if there are any patterns between NaN rows, starting with ***"Year"** column.

# %%
df[df["Year"].isnull()]
# Out:
#        Year Player  Pos  Age   Tm   G  GS  MP  PER  TS% ...   FT%  ORB  DRB  \
# 312     NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 487     NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 618     NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 779     NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 911     NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1021    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1128    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1236    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1348    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1459    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1577    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1682    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1808    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 1942    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 2078    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 2211    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 2347    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 2481    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 2659    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 2866    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 3068    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 3314    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 3580    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 3850    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 4096    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 4373    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 4648    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 5006    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 5380    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 5724    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# ...     ...    ...  ...  ...  ...  ..  ..  ..  ...  ... ...   ...  ...  ...
# 8662    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 9088    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 9526    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 9985    NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 10424   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 10882   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 11331   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 11812   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 12265   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 12810   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 13382   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 13929   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 14436   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 14933   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 15471   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 15972   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 16456   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 17042   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 17628   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 18192   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 18709   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 19305   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 19888   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 20467   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 21093   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 21645   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 22219   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 22831   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 23483   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
# 24062   NaN    NaN  NaN  NaN  NaN NaN NaN NaN  NaN  NaN ...   NaN  NaN  NaN
#
#        TRB  AST  STL  BLK  TOV  PF  PTS
# 312    NaN  NaN  NaN  NaN  NaN NaN  NaN
# 487    NaN  NaN  NaN  NaN  NaN NaN  NaN
# 618    NaN  NaN  NaN  NaN  NaN NaN  NaN
# 779    NaN  NaN  NaN  NaN  NaN NaN  NaN
# 911    NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1021   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1128   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1236   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1348   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1459   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1577   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1682   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1808   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1942   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 2078   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 2211   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 2347   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 2481   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 2659   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 2866   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 3068   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 3314   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 3580   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 3850   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 4096   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 4373   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 4648   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 5006   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 5380   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 5724   NaN  NaN  NaN  NaN  NaN NaN  NaN
# ...    ...  ...  ...  ...  ...  ..  ...
# 8662   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 9088   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 9526   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 9985   NaN  NaN  NaN  NaN  NaN NaN  NaN
# 10424  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 10882  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 11331  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 11812  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 12265  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 12810  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 13382  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 13929  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 14436  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 14933  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 15471  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 15972  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 16456  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 17042  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 17628  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 18192  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 18709  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 19305  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 19888  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 20467  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 21093  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 21645  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 22219  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 22831  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 23483  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 24062  NaN  NaN  NaN  NaN  NaN NaN  NaN
#
# [67 rows x 50 columns]

# %% [markdown]
# It turns out that whenever the **"Year"** row is NaN, the rest of the columns also have NaN. So, we can remove these rows without any concern. In order to remove them, we can extract the index values of these rows and provide it to `drop` function.

# %%
index2drop = df[df["Year"].isnull()].index  # we use the index attribute here
                                            # since, we have a dataframe
df.drop(index2drop, inplace=True)

# %% [markdown]
# Now, let's check the NaN values one more time. There seems to be a pattern between different attributes. We can use one of these attributes to observe the pattern.

# %%
df.isnull().sum()
# Out:
# Year         0
# Player       0
# Pos          0
# Age          8
# Tm           0
# G            0
# GS        6387
# MP         486
# PER        523
# TS%         86
# 3PAr      5783
# FTr         99
# ORB%      3832
# DRB%      3832
# TRB%      3053
# AST%      2069
# STL%      3832
# BLK%      3832
# TOV%      5042
# USG%      4984
# OWS         39
# DWS         39
# WS          39
# WS/48      523
# OBPM      3827
# DBPM      3827
# BPM       3827
# VORP      3827
# FG           0
# FGA          0
# FG%         99
# 3P        5695
# 3PA       5695
# 3P%       9206
# 2P           0
# 2PA          0
# 2P%        128
# eFG%        99
# FT           0
# FTA          0
# FT%        857
# ORB       3827
# DRB       3827
# TRB        312
# AST          0
# STL       3827
# BLK       3827
# TOV       4979
# PF           0
# PTS          0
# dtype: int64

# %%
df[df["ORB"].isnull()]
# Out:
#         Year            Player  Pos   Age   Tm     G  GS      MP   PER    TS%  \
# 0     1950.0   Curly Armstrong  G-F  31.0  FTW  63.0 NaN     NaN   NaN  0.368
# 1     1950.0      Cliff Barker   SG  29.0  INO  49.0 NaN     NaN   NaN  0.435
# 2     1950.0     Leo Barnhorst   SF  25.0  CHS  67.0 NaN     NaN   NaN  0.394
# 3     1950.0        Ed Bartels    F  24.0  TOT  15.0 NaN     NaN   NaN  0.312
# 4     1950.0        Ed Bartels    F  24.0  DNN  13.0 NaN     NaN   NaN  0.308
# 5     1950.0        Ed Bartels    F  24.0  NYK   2.0 NaN     NaN   NaN  0.376
# 6     1950.0       Ralph Beard    G  22.0  INO  60.0 NaN     NaN   NaN  0.422
# 7     1950.0        Gene Berce  G-F  23.0  TRI   3.0 NaN     NaN   NaN  0.275
# 8     1950.0     Charlie Black  F-C  28.0  TOT  65.0 NaN     NaN   NaN  0.346
# 9     1950.0     Charlie Black  F-C  28.0  FTW  36.0 NaN     NaN   NaN  0.362
# 10    1950.0     Charlie Black  F-C  28.0  AND  29.0 NaN     NaN   NaN  0.326
# 11    1950.0       Nelson Bobb   PG  25.0  PHW  57.0 NaN     NaN   NaN  0.396
# 3832  1973.0       Walt Wesley    C  28.0  TOT  57.0 NaN   474.0  10.3  0.405
# 3833  1973.0       Walt Wesley    C  28.0  CLE  12.0 NaN   110.0   7.8  0.344
# 3834  1973.0       Walt Wesley    C  28.0  PHO  45.0 NaN   364.0  11.1  0.424
# 3835  1973.0       Jerry West*   PG  34.0  LAL  69.0 NaN  2460.0  23.2  0.533
# 3836  1973.0     Paul Westphal   SG  22.0  BOS  60.0 NaN   482.0  14.2  0.490
# 3837  1973.0       John Wetzel   SG  28.0  ATL  28.0 NaN   504.0   6.8  0.483
# 3838  1973.0             Jo Jo   PG  26.0  BOS  82.0 NaN  3250.0  14.7  0.457
# 3839  1973.0      Sidney Wicks   PF  23.0  POR  80.0 NaN  3152.0  20.3  0.497
# 3840  1973.0    Lenny Wilkens*   PG  35.0  CLE  75.0 NaN  2973.0  19.3  0.518
# 3841  1973.0      Art Williams   PG  33.0  BOS  81.0 NaN   974.0  13.2  0.460
# 3842  1973.0     Nate Williams   SG  22.0  KCO  80.0 NaN  1979.0  12.9  0.504
# 3843  1973.0      Ron Williams   PG  28.0  GSW  73.0 NaN  1016.0  12.2  0.488
# 3844  1973.0      Lee Winfield   PG  25.0  SEA  53.0 NaN  1061.0  12.2  0.458
# 3845  1973.0   Harthorne Wingo   PF  25.0  NYK  13.0 NaN    59.0   8.1  0.406
# 3846  1973.0         Dave Wohl   PG  23.0  TOT  78.0 NaN  1933.0  10.4  0.488
# 3847  1973.0         Dave Wohl   PG  23.0  POR  22.0 NaN   393.0   9.6  0.459
# 3848  1973.0         Dave Wohl   PG  23.0  BUF  56.0 NaN  1540.0  10.6  0.495
# 3849  1973.0       Joby Wright   PF  22.0  SEA  77.0 NaN   931.0   9.2  0.478
#
#        ...      FT%  ORB  DRB     TRB    AST  STL  BLK  TOV     PF     PTS
# 0      ...    0.705  NaN  NaN     NaN  176.0  NaN  NaN  NaN  217.0   458.0
# 1      ...    0.708  NaN  NaN     NaN  109.0  NaN  NaN  NaN   99.0   279.0
# 2      ...    0.698  NaN  NaN     NaN  140.0  NaN  NaN  NaN  192.0   438.0
# 3      ...    0.559  NaN  NaN     NaN   20.0  NaN  NaN  NaN   29.0    63.0
# 4      ...    0.548  NaN  NaN     NaN   20.0  NaN  NaN  NaN   27.0    59.0
# 5      ...    0.667  NaN  NaN     NaN    0.0  NaN  NaN  NaN    2.0     4.0
# 6      ...    0.762  NaN  NaN     NaN  233.0  NaN  NaN  NaN  132.0   895.0
# 7      ...    0.000  NaN  NaN     NaN    2.0  NaN  NaN  NaN    6.0    10.0
# 8      ...    0.651  NaN  NaN     NaN  163.0  NaN  NaN  NaN  273.0   661.0
# 9      ...    0.632  NaN  NaN     NaN   75.0  NaN  NaN  NaN  140.0   382.0
# 10     ...    0.688  NaN  NaN     NaN   88.0  NaN  NaN  NaN  133.0   279.0
# 3831   ...    0.841  NaN  NaN   148.0  295.0  NaN  NaN  NaN  151.0   717.0
# 3832   ...    0.565  NaN  NaN   151.0   31.0  NaN  NaN  NaN   77.0   180.0
# 3833   ...    0.667  NaN  NaN    38.0    7.0  NaN  NaN  NaN   21.0    36.0
# 3834   ...    0.529  NaN  NaN   113.0   24.0  NaN  NaN  NaN   56.0   144.0
# 3835   ...    0.805  NaN  NaN   289.0  607.0  NaN  NaN  NaN  138.0  1575.0
# 3836   ...    0.779  NaN  NaN    67.0   69.0  NaN  NaN  NaN   88.0   245.0
# 3837   ...    0.824  NaN  NaN    58.0   39.0  NaN  NaN  NaN   41.0    98.0
# 3838   ...    0.781  NaN  NaN   414.0  498.0  NaN  NaN  NaN  185.0  1612.0
# 3839   ...    0.723  NaN  NaN   870.0  440.0  NaN  NaN  NaN  253.0  1906.0
# 3840   ...    0.828  NaN  NaN   346.0  628.0  NaN  NaN  NaN  221.0  1538.0
# 3841   ...    0.768  NaN  NaN   182.0  236.0  NaN  NaN  NaN  136.0   263.0
# 3842   ...    0.797  NaN  NaN   339.0  128.0  NaN  NaN  NaN  272.0   940.0
# 3843   ...    0.904  NaN  NaN    81.0  114.0  NaN  NaN  NaN  108.0   435.0
# 3844   ...    0.574  NaN  NaN   126.0  186.0  NaN  NaN  NaN   92.0   348.0
# 3845   ...    0.333  NaN  NaN    16.0    1.0  NaN  NaN  NaN    9.0    20.0
# 3846   ...    0.774  NaN  NaN   109.0  326.0  NaN  NaN  NaN  227.0   611.0
# 3847   ...    0.727  NaN  NaN    20.0   68.0  NaN  NaN  NaN   45.0   118.0
# 3848   ...    0.790  NaN  NaN    89.0  258.0  NaN  NaN  NaN  182.0   493.0
# 3849   ...    0.416  NaN  NaN   218.0   36.0  NaN  NaN  NaN  164.0   303.0
#
# [3827 rows x 50 columns]

# %%
df[df["ORB"].isnull()]["Year"].describe()
# Out:
# count    3827.000000
# mean     1962.375751
# std         7.762242
# min      1950.000000
# 25%      1955.000000
# 50%      1963.000000
# 75%      1970.000000
# max      1973.000000
# Name: Year, dtype: float64

# %% [markdown]
# It seems that **"Year"** column has an effect. Let's apply a filter on **"Year"** column so that we end up with an era in which NBA started to become a global phenomena. The first three-point shot is recorded on [October 12, 1979](http://www.wikizero.biz/index.php?q=aHR0cHM6Ly9lbi53aWtpcGVkaWEub3JnL3dpa2kvVGhyZWUtcG9pbnRfZmllbGRfZ29hbA), that is also the season when the rivalry between Magic Johnson and Larry Bird started.

# %%
df = df[df["Year"] > 1979]  # filtering on year column

# %%
df.isnull().sum()
# Out:
# Year         0
# Player       0
# Pos          0
# Age          0
# Tm           0
# G            0
# GS         692
# MP           0
# PER          5
# TS%         76
# 3PAr        88
# FTr         88
# ORB%         5
# DRB%         5
# TRB%         5
# AST%         5
# STL%         5
# BLK%         5
# TOV%        61
# USG%         5
# OWS          0
# DWS          0
# WS           0
# WS/48        5
# OBPM         0
# DBPM         0
# BPM          0
# VORP         0
# FG           0
# FGA          0
# FG%         88
# 3P           0
# 3PA          0
# 3P%       3511
# 2P           0
# 2PA          0
# 2P%        117
# eFG%        88
# FT           0
# FTA          0
# FT%        744
# ORB          0
# DRB          0
# TRB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PF           0
# PTS          0
# dtype: int64

# %% [markdown]
# Still, we have NaN values on some columns such as `FT%`, `FG%`, `3P%` and `2P%`. We can fill the NaN values on these columns.

# %%
matchings = {
    "FT%" : {
        "made": "FT",
        "attempted": "FTA"
    },
    "FG%": {
        "made": "FG",
        "attempted": "FGA"
    },
    "3P%": {
        "made": "3P",
        "attempted": "3PA"
    },
    "2P%": {
        "made": "2P",
        "attempted": "2PA"
    }
}

def compute_percentage(row, *args):
    """
    fills NaN values by computing made / attempted
    """
    percentage_attr = args[0]
    
    made = row[matchings[percentage_attr]["made"]]
    attempted = row[matchings[percentage_attr]["attempted"]]
    
    return made / attempted if attempted > 0 else 0  # to prevent zero division

for attr in matchings.keys():  # iterate over columns in which NaNs exist
    df.loc[df[attr].isnull(), [attr]] = df[df[attr].isnull()].apply(compute_percentage, axis=1, args=([attr]))

# %%
def compute_3PAr(row):
    """
    computes the share of 3-point shot attemps
    """
    two_points = row["2PA"]
    three_points = row["3PA"]
    total = two_points + three_points
    
    return three_points / total if total > 0 else 0

df.loc[df["3PAr"].isnull(), ["3PAr"]] = df[df["3PAr"].isnull()].apply(compute_3PAr, axis=1)

# %%
df.isnull().sum()  # let's leave other NaN values as they are
# Out:
# Year        0
# Player      0
# Pos         0
# Age         0
# Tm          0
# G           0
# GS        692
# MP          0
# PER         5
# TS%        76
# 3PAr        0
# FTr        88
# ORB%        5
# DRB%        5
# TRB%        5
# AST%        5
# STL%        5
# BLK%        5
# TOV%       61
# USG%        5
# OWS         0
# DWS         0
# WS          0
# WS/48       5
# OBPM        0
# DBPM        0
# BPM         0
# VORP        0
# FG          0
# FGA         0
# FG%         0
# 3P          0
# 3PA         0
# 3P%         0
# 2P          0
# 2PA         0
# 2P%         0
# eFG%       88
# FT          0
# FTA         0
# FT%         0
# ORB         0
# DRB         0
# TRB         0
# AST         0
# STL         0
# BLK         0
# TOV         0
# PF          0
# PTS         0
# dtype: int64

# %% [markdown]
# #### Converting data types

# %% [markdown]
# In the dataframe, **"year"** column is parsed as a float. Let's convert it to a datetime.

# %%
df["Year"].dtype
# Out:
# dtype('float64')

# %%
df["Year"].describe()
# Out:
# count    18896.000000
# mean      2000.291384
# std         10.688185
# min       1980.000000
# 25%       1992.000000
# 50%       2001.000000
# 75%       2010.000000
# max       2017.000000
# Name: Year, dtype: float64

# %%
df["Year"] = pd.to_datetime(df["Year"].astype(np.int32), format="%Y")

# %%
df["Year"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Now, let's write the result to a file and continue working on it in another notebook.

# %%
filename = "nba_players_modified.csv"

df.to_csv(join(d_path, filename), index=False)
